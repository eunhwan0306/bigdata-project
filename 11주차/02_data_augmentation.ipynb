# %%
pip install --upgrade jupyter ipywidgets
# Out:
# Collecting jupyter
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting notebook (from jupyter)
#   Using cached notebook-7.5.6-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: ipykernel in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter) (7.2.0)
# Requirement already satisfied: jupyterlab in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter) (4.5.7)
# Requirement already satisfied: comm>=0.1.3 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipywidgets) (9.13.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipywidgets) (5.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: psutil>=7 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipykernel->jupyter) (1.8.20)
# Requirement already satisfied: jupyter-client>=8.8.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipykernel->jupyter) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipykernel->jupyter) (26.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from ipykernel->jupyter) (6.5.5)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab->jupyter) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab->jupyter) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab->jupyter) (70.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbconvert->jupyter) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbconvert->jupyter) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: anyio in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.13.0)
# Requirement already satisfied: certifi in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-client>=8.8.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter) (4.9.6)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.25.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.2)
# Requirement already satisfied: wcwidth in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.6.3)
# Requirement already satisfied: fqdn in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in c:\users\6-112\desktop\빅데이터분석프로그래밍\bigdata-project-b-주은환\venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2025.3)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached notebook-7.5.6-py3-none-any.whl (14.6 MB)
# Installing collected packages: ipywidgets, jupyter-console, notebook, jupyter
# Successfully installed ipywidgets-8.1.8 jupyter-1.1.1 jupyter-console-6.6.3 notebook-7.5.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 실습 3·4 — 이미지 데이터 증강 (2교시)
#
# **학습 목표**
# - 과적합과 일반화를 이해하고, 데이터 증강이 왜 필요한지 설명한다.
# - `torchvision.transforms`의 핵심 증강 8가지를 직접 적용한다.
# - `Compose`로 학습용/검증용 파이프라인을 분리해서 만든다.
# - CIFAR-10에 증강을 적용하고 매번 다른 결과가 나오는 것을 확인한다.
#
# **사전 조건**
# - 1교시 노트북(`01_image_basics.ipynb`) 완료, `preprocess` 파이프라인 이해
# - `sample_images/dog.jpg` 존재

# %% [markdown]
# ## 셀 [0] — 한글 폰트 + 공통 import

# %%
import platform
import matplotlib.pyplot as plt
from matplotlib import rcParams

if platform.system() == "Windows":
    rcParams["font.family"] = "Malgun Gothic"
elif platform.system() == "Darwin":
    rcParams["font.family"] = "AppleGothic"
rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 셀 [1] — 이미지 로드 + 시각화 보조 함수

# %%
from PIL import Image
from torchvision import transforms

img = Image.open("sample_images/dog.jpg").convert("RGB")

def show(images, titles, ncols=4):
    """이미지 리스트를 grid로 시각화하는 보조 함수"""
    n = len(images)
    nrows = (n + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 3, nrows * 3))
    axes = axes.flatten() if n > 1 else [axes]
    for ax, im, t in zip(axes, images, titles):
        ax.imshow(im); ax.set_title(t); ax.axis("off")
    for ax in axes[len(images):]:
        ax.axis("off")
    plt.tight_layout(); plt.show()

print(f"원본 크기: {img.size}")
# Out:
# 원본 크기: (330, 219)

# %% [markdown]
# ## 셀 [2] — RandomHorizontalFlip (좌우 반전)
#
# `p=1.0`으로 항상 반전하여 시연. 실제 학습에서는 `p=0.5`.

# %%
hflip = transforms.RandomHorizontalFlip(p=1.0)
show([img, hflip(img)], ["원본", "좌우 반전"], ncols=2)

# %% [markdown]
# ## 셀 [3] — RandomRotation (무작위 회전)
#
# 같은 변환을 4번 적용해 무작위성을 확인. 모서리 검은 빈 공간이 보입니다.

# %%
rotate = transforms.RandomRotation(degrees=30)
rotated = [rotate(img) for _ in range(4)]
show([img] + rotated,
     ["원본", "회전 1", "회전 2", "회전 3", "회전 4"], ncols=5)

# %% [markdown]
# ### 셀 [3-1] — fill / expand 옵션 비교
#
# 회전 모서리 빈 공간 처리. `fill=128`(회색), `expand=True`(이미지 자체 확장).

# %%
rotate_fill = transforms.RandomRotation(degrees=30, fill=128)
rotate_expand = transforms.RandomRotation(degrees=30, expand=True)
show(
    [img, rotate(img), rotate_fill(img), rotate_expand(img)],
    ["원본", "기본 (검정)", "fill=128 (회색)", "expand=True"],
    ncols=4,
)

# %% [markdown]
# ## 셀 [4] — RandomResizedCrop (자르기 + 확대)
#
# 원본의 50~100% 영역을 무작위로 잘라 224×224로 리사이즈.

# %%
crop = transforms.RandomResizedCrop(
    size=224,
    scale=(0.5, 1.0),
    ratio=(0.75, 1.33),
)
cropped = [crop(img) for _ in range(4)]
show([img] + cropped,
     ["원본", "Crop 1", "Crop 2", "Crop 3", "Crop 4"], ncols=5)

# %% [markdown]
# ### 셀 [4-1] — scale을 극단적으로 작게 했을 때 (Aliasing 확인)
#
# `scale=(0.08, 0.1)`로 원본의 ~10%만 추출 → 224×224로 강제 확대. 정보량은 그대로인데 픽셀만 늘어남.

# %%
crop_extreme = transforms.RandomResizedCrop(size=224, scale=(0.08, 0.1))
extreme = [crop_extreme(img) for _ in range(4)]
show([img] + extreme,
     ["원본", "극단 Crop 1", "극단 Crop 2", "극단 Crop 3", "극단 Crop 4"], ncols=5)

# %% [markdown]
# ## 셀 [5] — ColorJitter (밝기·대비·채도·색조)

# %%
jitter = transforms.ColorJitter(
    brightness=0.3,
    contrast=0.3,
    saturation=0.3,
    hue=0.1,
)
jittered = [jitter(img) for _ in range(4)]
show([img] + jittered,
     ["원본", "Jitter 1", "Jitter 2", "Jitter 3", "Jitter 4"], ncols=5)

# %% [markdown]
# ## 셀 [6] — RandomGrayscale (흑백화)

# %%
gray = transforms.RandomGrayscale(p=1.0)
show([img, gray(img)], ["원본", "흑백"], ncols=2)

# %% [markdown]
# ## 셀 [7] — GaussianBlur (가우시안 흐림)

# %%
blur = transforms.GaussianBlur(kernel_size=11, sigma=(0.1, 5.0))
blurred = [blur(img) for _ in range(4)]
show([img] + blurred,
     ["원본", "Blur 1", "Blur 2", "Blur 3", "Blur 4"], ncols=5)

# %% [markdown]
# ## 셀 [8] — 학습용 / 검증용 파이프라인 분리 ★
#
# **학습용**: 증강 ON / **검증용**: 결정적 전처리만.

# %%
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

print("train_transform / val_transform 정의 완료")
# Out:
# train_transform / val_transform 정의 완료

# %% [markdown]
# ## 셀 [9] — 같은 사진에 12번 적용 (시각화용, Normalize 제외)
#
# 원본 1장 → 12장이 모두 다른 사진처럼 보임.

# %%
viz_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
])

augmented = [viz_transform(img) for _ in range(12)]
show(augmented, [f"증강 {i+1}" for i in range(12)], ncols=4)

# %% [markdown]
# ## 셀 [10] — CIFAR-10에 증강 적용
#
# `with_transform`은 꺼낼 때마다 함수를 실행 → 매번 다른 결과.

# %%
from datasets import load_dataset

ds = load_dataset("uoft-cs/cifar10")

def transform_train(batch):
    batch["pixel_values"] = [train_transform(img.convert("RGB")) for img in batch["img"]]
    return batch

def transform_val(batch):
    batch["pixel_values"] = [val_transform(img.convert("RGB")) for img in batch["img"]]
    return batch

ds_train = ds["train"].with_transform(transform_train)
ds_test = ds["test"].with_transform(transform_val)

first1 = ds_train[0]["pixel_values"]
first2 = ds_train[0]["pixel_values"]
print(f"같은 인덱스 두 번 호출 — 같은 결과? {(first1 == first2).all().item()}")
# Out:
# 같은 인덱스 두 번 호출 — 같은 결과? False

# %% [markdown]
# ## 셀 [11] — CIFAR-10 강아지 한 장을 8번 변형해 보기 (denormalize 시각화)

# %%
import torch

def denormalize(t):
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    return (t * std + mean).clamp(0, 1)

label_names = ds["train"].features["label"].names
dog_idx = next(i for i in range(100) if ds["train"][i]["label"] == 5)

variations = [denormalize(ds_train[dog_idx]["pixel_values"]).permute(1, 2, 0)
              for _ in range(8)]
show(variations, [f"강아지 변형 {i+1}" for i in range(8)], ncols=4)

# %% [markdown]
# ## 셀 [12] — 학생 자율 실습: 내가 만든 증강 조합 ★
#
# 아래 파라미터를 자유롭게 바꿔 결과를 비교해보세요.
# 여유가 있다면 `img` 대신 본인 휴대폰 사진(`sample_images/my_phone.jpg`)을 넣어보세요.

# %%
my_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224, scale=(0.7, 1.0)),     # ← scale 범위 바꾸기
    transforms.RandomHorizontalFlip(p=0.5),                   # ← 확률 바꾸기
    transforms.RandomRotation(degrees=30),                    # ← 각도 바꾸기
    transforms.ColorJitter(brightness=0.4, contrast=0.4,
                           saturation=0.4, hue=0.1),          # ← 강도 바꾸기
    transforms.RandomGrayscale(p=0.2),                        # ← 흑백 확률 바꾸기
    # transforms.GaussianBlur(kernel_size=5),                  # ← 주석 풀어보기
])

mine = [my_transform(img) for _ in range(8)]
show(mine, [f"내 증강 {i+1}" for i in range(8)], ncols=4)

# %% [markdown]
# ## 셀 [13] — 증강 퀴즈 (어떤 변환이 적용됐을까?)
#
# 라벨을 가린 채로 보여주고, 학생들이 어떤 증강인지 맞히기.

# %%
quiz_transforms = {
    "A": transforms.RandomRotation(degrees=(45, 45)),
    "B": transforms.ColorJitter(brightness=(0.3, 0.3)),
    "C": transforms.RandomHorizontalFlip(p=1.0),
    "D": transforms.GaussianBlur(kernel_size=15, sigma=3.0),
    "E": transforms.RandomGrayscale(p=1.0),
    "F": transforms.RandomResizedCrop(224, scale=(0.3, 0.3)),
}

quiz_images = [t(img) for t in quiz_transforms.values()]
quiz_labels = list(quiz_transforms.keys())
show(quiz_images, quiz_labels, ncols=3)

print("정답:", {k: type(v).__name__ for k, v in quiz_transforms.items()})
# Out:
# 정답: {'A': 'RandomRotation', 'B': 'ColorJitter', 'C': 'RandomHorizontalFlip', 'D': 'GaussianBlur', 'E': 'RandomGrayscale', 'F': 'RandomResizedCrop'}

# %% [markdown]
# ---
# ## 2교시 마무리 체크리스트
#
# - [ ] 셀 [3]에서 같은 변환을 4번 적용했을 때 결과가 매번 달라짐을 확인했다.
# - [ ] 셀 [8]에서 `train_transform` ≠ `val_transform`임을 이해했다.
# - [ ] 셀 [10]에서 `with_transform`이 매번 다른 결과를 낸다 (`False`)는 것을 봤다.
# - [ ] 셀 [12]에서 본인이 만든 조합으로 결과를 시각화했다.
#
# **다음 시간(3교시) 예고**: `pipeline("image-classification")` 1줄로 ViT 사전학습 모델을 불러와 본인 사진을 분류해봅니다.
